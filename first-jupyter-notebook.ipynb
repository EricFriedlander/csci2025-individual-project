# %% [markdown]
# # Here's my title

# %% [markdown]
# Welcome to my new **JUPYTER NOTBOOK**.

# %%
library(dplyr)
library(ggplot2)
library(nycflights13)

# %%
z
ggplot(flights, aes(x=seconds)) +
  geom_histogram(fill = "blue")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
